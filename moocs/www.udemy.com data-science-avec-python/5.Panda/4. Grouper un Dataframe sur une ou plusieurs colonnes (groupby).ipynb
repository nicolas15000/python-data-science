# %%
# GroupBy sur un dataframe
# lire un fichier et en faire un dataframe pour gérer .
# On trouve ce bon fichier sur kaggle.com
import pandas as pd
google_app = pandas.read_table("googleplaystore.csv",sep=",")
google_app
# Supprimer les lignes avec NAN /  Nettoyer le tableau
google_app_sansNan = google_app.dropna()
google_app_sansNan
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Obtenir des infos sur un groupby()
google_app_sansNan.groupby("Category").describe()
# Out:
#                      Rating
#                       count      mean       std  min    25%  50%    75%  max
# Category
# ART_AND_DESIGN         61.0  4.377049  0.328326  3.4  4.100  4.4  4.700  5.0
# AUTO_AND_VEHICLES      73.0  4.190411  0.543692  2.1  4.000  4.3  4.600  4.9
# BEAUTY                 42.0  4.278571  0.362603  3.1  4.000  4.3  4.575  4.9
# BOOKS_AND_REFERENCE   178.0  4.346067  0.429046  2.7  4.100  4.5  4.600  5.0
# BUSINESS              303.0  4.121452  0.624422  1.0  3.900  4.3  4.500  5.0
# COMICS                 58.0  4.155172  0.537758  2.8  3.825  4.4  4.500  5.0
# COMMUNICATION         328.0  4.158537  0.426192  1.0  4.000  4.3  4.400  5.0
# DATING                195.0  3.970769  0.630510  1.0  3.700  4.1  4.400  5.0
# EDUCATION             155.0  4.389032  0.251894  3.5  4.200  4.4  4.600  4.9
# ENTERTAINMENT         149.0  4.126174  0.302556  3.0  3.900  4.2  4.300  4.7
# EVENTS                 45.0  4.435556  0.419499  2.9  4.200  4.5  4.700  5.0
# ...

# %%
# Obtenir des infos sur un groupby()
google_app = pandas.read_table("googleplaystore.csv",sep=",")
google_app
# Supprimer les lignes avec NAN /  Nettoyer le tableau
google_app_sansNan = google_app.dropna()
google_app_sansNan
df1 = google_app_sansNan.groupby("Category").describe().reset_index()
df1
# Out:
#                Category  Rating                                              \
#                           count      mean       std  min    25%  50%    75%
# 0        ART_AND_DESIGN    61.0  4.377049  0.328326  3.4  4.100  4.4  4.700
# 1     AUTO_AND_VEHICLES    73.0  4.190411  0.543692  2.1  4.000  4.3  4.600
# 2                BEAUTY    42.0  4.278571  0.362603  3.1  4.000  4.3  4.575
# 3   BOOKS_AND_REFERENCE   178.0  4.346067  0.429046  2.7  4.100  4.5  4.600
# 4              BUSINESS   303.0  4.121452  0.624422  1.0  3.900  4.3  4.500
# 5                COMICS    58.0  4.155172  0.537758  2.8  3.825  4.4  4.500
# 6         COMMUNICATION   328.0  4.158537  0.426192  1.0  4.000  4.3  4.400
# 7                DATING   195.0  3.970769  0.630510  1.0  3.700  4.1  4.400
# 8             EDUCATION   155.0  4.389032  0.251894  3.5  4.200  4.4  4.600
# 9         ENTERTAINMENT   149.0  4.126174  0.302556  3.0  3.900  4.2  4.300
# ...

# %%
# A vérifier ne fonctionne pas : https://stackoverflow.com/questions/56000762/sorting-the-pandas-dataframe-describe-output
df1 = df1.sort_values('count', ascending=False)
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-d9f46553ff22> in <module>
# ----> 1 df1 = df1.sort_values('count', ascending=False)
#       2 df1
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'count'
