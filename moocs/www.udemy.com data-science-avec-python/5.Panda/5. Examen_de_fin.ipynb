# %%
# EXAMEN  : Etudier le marché Android Store

# 1. Quels sont les noms, les genres et les catégories des applications les plus installées sur le google Play ?

# Réponse : On veut déjà connaitres les noms des apps les plus téléchargées.
# a) On commence par lire le fichier
import pandas as pd
google_app = pd.read_table("googleplaystore.csv",sep=",")
google_app

# On rêgle l'affichage du tableau pour bien voir toutes les colonnes dans jupyterlab
# On affiche que 10 lignes
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 500)
# Largeur de l'écran
pd.set_option('display.width', 400)

# %%
# b) Pour trier par nombre d'installs, il faut oter le caractère + et , de chaque ligne de la colonne "Installs", puis caster en INT :

# Remplacer des var  qualitatives en quantitatives 
# Retirer le + des vars dans la col "Installs" , les virgules et le free
google_app["Installs"] = google_app["Installs"].apply(lambda x: x.replace(",",""))
google_app["Installs"] = google_app["Installs"].apply(lambda x: x.replace("+",""))
google_app["Installs"] = google_app["Installs"].apply(lambda x: x.replace("Free","0"))

# Caster la colonne Installs en INT :
google_app['installs'] = google_app['Installs'].astype(float)    

# Montrer les 5 premières apps les plus installées
google_app.sort_values(by='Installs', ascending=False)
# Out:
#                                                     App            Category  Rating   Reviews                Size   Installs  Type    Price Content Rating            Genres       Last Updated               Current Ver         Android Ver     installs
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS     4.7  24900999  Varies with device  500000000  Free        0       Everyone             Tools     August 4, 2018                     4.6.6  Varies with device  500000000.0
# 474                         LINE: Free Calls & Messages       COMMUNICATION     4.2  10790289  Varies with device  500000000  Free        0       Everyone     Communication      July 26, 2018        Varies with device  Varies with device  500000000.0
# ...

# %%
# Réponse 2 : Connaitre quels est le genre des apps les plus téléchargées

# On groupe par genre
Genres = google_app.groupby(["Genres"])

# Avec describe, on voit que le genre ayant le plus d'apps téléchargées est Action
Genres.describe(include ="all")
# Out:
#                                         App                                                                                                   Category                                                               Rating                                                               Reviews                                                          Size                                            \
#                                       count unique                                                top freq mean  std  min  25%  50%  75%  max    count unique            top freq mean  std  min  25%  50%  75%  max  count unique top freq      mean       std  min   25%  50%  75%  max   count unique      top freq mean  std  min  25%  50%  75%  max count unique                 top freq mean  std
# Genres
# ...

# %%
# Réponse 3 : On veut connaitre les catégories des apps les plus téléchargées.

# On groupe par category
Categories = google_app.groupby(["Category"])

#On peut afficher chaque lignes par categories
#for grp in Categories:
    #print (grp)

# Avec describe, on voit que la catégorie ayant le plus d'apps téléchargées est Tools, (outils)
Categories.describe(include ="all")
# Out:
#                       App                                                                                                   Rating                                                                       Reviews                                                       Size                                                                    Installs                                                     \
#                     count unique                                                top freq mean  std  min  25%  50%  75%  max  count unique top freq       mean       std   min    25%   50%     75%   max   count unique   top freq mean  std  min  25%  50%  75%  max count unique                 top freq mean  std  min  25%  50%  75%  max    count unique      top freq mean  std  min  25%  50%  75%
# Category
# ...

# %%
# Examen question 2 : Quel est le plus grand nombre de reviews , Quel est le nom est la note globale de l'paplicaiton concernée ?

# %%
#Avec sort-values ( bizarre, ça ne sort pas le même qu'en question 1 ):
google_app.sort_values(by='Reviews', ascending=False)
# Son nom est GollerCepte Live Score 	et sa note 4.2
# Out:
#                                     App             Category  Rating Reviews  Size Installs  Type   Price Content Rating             Genres       Last Updated Current Ver   Android Ver   installs
# 2989             GollerCepte Live Score               SPORTS     4.2    9992   31M  1000000  Free       0       Everyone             Sports       May 23, 2018         6.5    4.1 and up  1000000.0
# 4970       Ad Block REMOVER - NEED ROOT                TOOLS     3.3     999   91k   100000  Free       0       Everyone              Tools  December 17, 2013         3.2    2.2 and up   100000.0
# 2723                SnipSnap Coupon App             SHOPPING     4.2    9975   18M  1000000  Free       0       Everyone           Shopping   January 22, 2018         1.4    4.3 and up  1000000.0
# 2705                SnipSnap Coupon App             SHOPPING     4.2    9975   18M  1000000  Free       0       Everyone           Shopping   January 22, 2018         1.4    4.3 and up  1000000.0
# ...

# %%
#Avec column.max()
column = google_app["Reviews"]
max_value = column.max()
print(max_value)
# Out:
# 9992

# %%
# Examen question 3 : Afficher les colonnes 2,5,6 et les lignes 3 à 16 du dataframe :
